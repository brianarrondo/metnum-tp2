# %% [markdown]
# # Experimentación - Gráficos

# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Test 1: Knn variando la cantidad de vecinos

# %%
data = pd.read_csv('tests_csv/test1.csv')

data
# Out:
#     Neighbors  Accuracy  Total time  Pred time Method
# 0           1     0.858    0.042653   0.039348    KNN
# 1           2     0.838    0.038575   0.035924    KNN
# 2           3     0.855    0.037955   0.035375    KNN
# 3           4     0.850    0.039290   0.036581    KNN
# 4           5     0.840    0.038786   0.036247    KNN
# 5           6     0.841    0.038451   0.035838    KNN
# 6           7     0.848    0.037485   0.034937    KNN
# 7           8     0.838    0.036793   0.034270    KNN
# 8           9     0.831    0.035299   0.032935    KNN
# 9          10     0.831    0.035061   0.032690    KNN
# 10         11     0.831    0.034953   0.032576    KNN
# 11         12     0.819    0.034952   0.032605    KNN
# 12         13     0.821    0.035489   0.032990    KNN
# 13         14     0.825    0.035324   0.032877    KNN
# 14         15     0.817    0.034936   0.032583    KNN
# 15         16     0.814    0.034742   0.032414    KNN
# 16         17     0.811    0.035578   0.033202    KNN
# 17         18     0.807    0.034852   0.032502    KNN
# 18         19     0.796    0.035262   0.032891    KNN
# 19         20     0.797    0.035356   0.032968    KNN
# 20         21     0.794    0.034945   0.032621    KNN
# 21         22     0.793    0.034706   0.032381    KNN
# 22         23     0.787    0.035144   0.032790    KNN
# 23         24     0.785    0.034778   0.032442    KNN
# 24         25     0.788    0.034957   0.032631    KNN
# 25         26     0.780    0.034975   0.032628    KNN
# 26         27     0.776    0.035805   0.033311    KNN
# 27         28     0.772    0.034952   0.032610    KNN
# 28         29     0.770    0.034965   0.032639    KNN

# %%
sns.lineplot(x='Neighbors', y='Accuracy', hue='Method', data=data)
plt.title("Test 1 - Accuracy")
# Out:
# Text(0.5, 1.0, 'Test 1 - Accuracy')

# %%
dataTotal = data.drop(columns='Pred time').rename(columns={'Total time': 'Time', 'Method': 'Time type'})
dataTotal['Time type'] = 'Total'

dataPred = data.drop(columns='Total time').rename(columns={'Pred time': 'Time', 'Method': 'Time type'})
dataPred['Time type'] = 'Prediction'

dataTime = pd.concat([dataTotal, dataPred])

# %%
sns.lineplot(x='Neighbors', y='Time', hue='Time type', data=dataTime)
plt.title("Test 1 - KNN Time")
# Out:
# Text(0.5, 1.0, 'Test 1 - KNN Time')

# %% [markdown]
# ## Test 2: PCA + KNN variando la cantidad de componentes principales

# %%
data = pd.read_csv('tests_csv/test2.csv')

data
# Out:
#     Components  Accuracy  Total time  Pred time     Method
# 0            1     0.274    0.097350   0.003992  PCA + KNN
# 1            2     0.394    0.109370   0.004218  PCA + KNN
# 2            3     0.483    0.132100   0.004326  PCA + KNN
# 3            4     0.620    0.145140   0.004261  PCA + KNN
# 4            5     0.670    0.189142   0.004416  PCA + KNN
# 5            6     0.773    0.200750   0.004259  PCA + KNN
# 6            7     0.776    0.224773   0.004435  PCA + KNN
# 7            8     0.791    0.274271   0.004400  PCA + KNN
# 8            9     0.822    0.294739   0.004516  PCA + KNN
# 9           10     0.824    0.323700   0.004394  PCA + KNN
# 10          11     0.827    0.337037   0.004528  PCA + KNN
# 11          12     0.846    0.363855   0.004423  PCA + KNN
# 12          13     0.851    0.397211   0.004549  PCA + KNN
# 13          14     0.864    0.439800   0.004500  PCA + KNN
# 14          15     0.868    0.521305   0.005343  PCA + KNN
# 15          16     0.869    0.521182   0.004514  PCA + KNN
# 16          17     0.878    0.557997   0.004808  PCA + KNN
# 17          18     0.864    0.580042   0.004604  PCA + KNN
# 18          19     0.866    0.655258   0.004809  PCA + KNN
# 19          20     0.872    0.733403   0.004799  PCA + KNN
# 20          21     0.872    0.746324   0.004817  PCA + KNN
# 21          22     0.879    0.778698   0.004666  PCA + KNN
# 22          23     0.870    0.894425   0.004859  PCA + KNN
# 23          24     0.869    0.974058   0.004757  PCA + KNN
# 24          25     0.868    1.009782   0.004899  PCA + KNN
# 25          26     0.860    1.093627   0.004777  PCA + KNN
# 26          27     0.859    1.198015   0.004899  PCA + KNN
# 27          28     0.861    1.229607   0.004869  PCA + KNN
# 28          29     0.867    1.305796   0.004980  PCA + KNN

# %%
sns.lineplot(x='Components', y='Accuracy', hue='Method', data=data)
plt.title("Test 2 - Accuracy")
# Out:
# Text(0.5, 1.0, 'Test 2 - Accuracy')

# %%
dataTotal = data.drop(columns='Pred time').rename(columns={'Total time': 'Time', 'Method': 'Time type'})
dataTotal['Time type'] = 'Total'

dataPred = data.drop(columns='Total time').rename(columns={'Pred time': 'Time', 'Method': 'Time type'})
dataPred['Time type'] = 'Prediction'

dataTime = pd.concat([dataTotal, dataPred])

# %%
grid = sns.lineplot(x='Components', y='Time', hue='Time type', data=dataTime)
grid.set(yscale="log")
plt.title("Test 2 - PCA + KNN Time")
# Out:
# Text(0.5, 1.0, 'Test 2 - PCA + KNN Time')

# %% [markdown]
# ## Test 3: Comparacion de accuracy y time

# %%
data = pd.read_csv('tests_csv/test3.csv')

data
# Out:
#      K  Accuracy  Total Time  Pred Time     Method
# 0    3  0.832833    0.078017   0.075632        KNN
# 1    4  0.836000    0.066059   0.063994        KNN
# 2    5  0.836000    0.060265   0.056765        KNN
# 3    6  0.841365    0.051933   0.048487        KNN
# 4    7  0.840040    0.046630   0.043115        KNN
# 5    8  0.837000    0.043301   0.039451        KNN
# 6    9  0.839840    0.039035   0.035227        KNN
# 7   10  0.840000    0.035926   0.032524        KNN
# 8   11  0.840404    0.032921   0.029348        KNN
# 9   12  0.842369    0.031726   0.028015        KNN
# 10  13  0.841093    0.029218   0.025332        KNN
# 11  14  0.848089    0.027745   0.023958        KNN
# 12  15  0.840404    0.026035   0.022565        KNN
# 13  16  0.842742    0.025591   0.021600        KNN
# 14  17  0.848884    0.023859   0.020462        KNN
# 15  18  0.842424    0.022927   0.019179        KNN
# 16  19  0.842105    0.021938   0.018116        KNN
# 17  19  0.844845    0.511554   0.011310  KNN + PCA
# 18  19  0.857000    0.462360   0.009606  KNN + PCA
# 19  19  0.858000    0.494019   0.008209  KNN + PCA
# 20  19  0.867470    0.510342   0.007202  KNN + PCA
# 21  19  0.867203    0.469692   0.006256  KNN + PCA
# 22  19  0.865000    0.460748   0.005654  KNN + PCA
# 23  19  0.870871    0.467183   0.005085  KNN + PCA
# 24  19  0.868000    0.487234   0.004619  KNN + PCA
# 25  19  0.869697    0.466774   0.004216  KNN + PCA
# 26  19  0.874498    0.483666   0.003909  KNN + PCA
# 27  19  0.870445    0.471758   0.003643  KNN + PCA
# 28  19  0.864185    0.496889   0.003399  KNN + PCA
# 29  19  0.862626    0.491660   0.003234  KNN + PCA
# 30  19  0.867944    0.503099   0.003045  KNN + PCA
# 31  19  0.870183    0.469652   0.002851  KNN + PCA
# 32  19  0.863636    0.475615   0.002689  KNN + PCA
# 33  19  0.865385    0.464891   0.002543  KNN + PCA

# %%
sns.lineplot(x='K', y='Accuracy', hue='Method', data=data)
plt.title("Test 3 - Accuracy")
# Out:
# Text(0.5, 1.0, 'Test 3 - Accuracy')

# %%
sns.lineplot(x='K', y='Total Time', hue='Method', data=data)
plt.title("Test 3 - Total Time")
# Out:
# Text(0.5, 1.0, 'Test 3 - Total Time')

# %%
sns.lineplot(x='K', y='Pred Time', hue='Method', data=data)
plt.title("Test 3 - Prediction Time")
# Out:
# Text(0.5, 1.0, 'Test 3 - Prediction Time')
